# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
import lightgbm as lgb
from sklearn.metrics import f1_score
import numpy as np
from contextlib import contextmanager
import time
import sys
import gc 
sys.path.append("../fraud_detection/src/")
from util import s_to_time_format, string_to_datetime,hour_to_range

CATEGORY = ['ecfg', 'flbmk', 'flg_3dsmk', 'insfg', 'ovrlt', 'scity', 'csmcu', 'cano', 'mchno', 'hcefg', 'bacno', 'contp', 'etymd', 'acqic']

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))
    
def main(args):
    with timer("Process train/test application"):
        #-------------------------
        # load dataset
        #-------------------------
        df_train = pd.read_csv(args.train_file)
        df_test = pd.read_csv(args.test_file)

        #-------------------------
        # pre-processing
        #-------------------------

        for cat in CATEGORY:
            df_train[cat] = df_train[cat].astype('category')#.cat.codes
            df_test[cat] = df_test[cat].astype('category')
            
        print("Train application df shape:", df_train.shape)
        print("Test application df shape:", df_test.shape)
        
        for df in [df_train, df_test]:
            # pre-processing
            df["loctm_"] = df.loctm.astype(int).astype(str)
            df.loctm_ = df.loctm_.apply(s_to_time_format).apply(string_to_datetime)
            # time-related feature
            df["loctm_hour_of_day"] = df.loctm_.apply(lambda x: x.hour).astype('category')
            df["loctm_minute_of_hour"] = df.loctm_.apply(lambda x: x.minute)
            df["loctm_second_of_min"] = df.loctm_.apply(lambda x: x.second)
            #df["loctm_absolute_time"] = [h*60+m for h,m in zip(df.loctm_hour_of_day,df.loctm_minute_of_hour)]
            df["hour_range"] = df.loctm_.apply(lambda x: hour_to_range(x.hour)).astype("category")
            # removed the columns no need
            df.drop(columns = ["loctm_"], axis = 1, inplace = True)
    return df_train, df_test

# %%
args = {
 "train_file":"/data/yunrui_li/fraud/dataset/train.csv",
 "test_file":"/data/yunrui_li/fraud/dataset/test.csv",
 "result_path":"/data/yunrui_li/fraud/fraud_detection/result/submission.csv",
 "feature_selection":False,
 "feature_importance_plot": True,
 "SEED": 1030,
 "NUM_FOLDS": 2, # 5
 "CPU_USE_RATE":1.0,
 "STRATIFIED": True,
 "TEST_NULL_HYPO":False,
 "NUM_LEAVES":31,
 "COLSAMPLE_BYTREE":1.0,
 "SUBSAMPLE": 1.0,
 "SUBSAMPLE_FREQ": 0,
 "MAX_DEPTH": -1,
 "REG_ALPHA": 0.0,
 "REG_LAMBDA": 0.0,
 "MIN_SPLIT_GAIN": 0.0,
 "MIN_CHILD_WEIGHT": 0.001,
 "MAX_BIN": 255,
 "SCALE_POS_WEIGHT": 3
    
}
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self
args = AttrDict(args)
args
# Out:
# {'train_file': '/data/yunrui_li/fraud/dataset/train.csv',
#  'test_file': '/data/yunrui_li/fraud/dataset/test.csv',
#  'result_path': '/data/yunrui_li/fraud/fraud_detection/result/submission.csv',
#  'feature_selection': False,
#  'feature_importance_plot': True,
#  'SEED': 1030,
#  'NUM_FOLDS': 2,
#  'CPU_USE_RATE': 1.0,
#  'STRATIFIED': True,
#  'TEST_NULL_HYPO': False,
#  'NUM_LEAVES': 31,
#  'COLSAMPLE_BYTREE': 1.0,
#  'SUBSAMPLE': 1.0,
#  'SUBSAMPLE_FREQ': 0,
#  'MAX_DEPTH': -1,
#  'REG_ALPHA': 0.0,
#  'REG_LAMBDA': 0.0,
#  'MIN_SPLIT_GAIN': 0.0,
#  'MIN_CHILD_WEIGHT': 0.001,
#  'MAX_BIN': 255,
#  'SCALE_POS_WEIGHT': 3}

# %%
df_train, df_test = main(args)
# Out:
# Train application df shape: (1521787, 23)
# Test application df shape: (421665, 22)
# Process train/test application - done in 79s

# %%
# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df_train, df_test, nan_as_category = True):
    df = pd.concat([df_train, df_test], axis = 0)
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
df = pd.concat([df_train, df_test], axis = 0)

# %%
original_columns = list(df.columns)
# categorical_columns = [col for col in df.columns if df[col].dtype == 'object']

# %%
CATEGORY = ['ecfg', 'flbmk', 'flg_3dsmk', 'insfg', 
            'ovrlt', 'scity', 'csmcu', 'cano', 
            'mchno', 'hcefg', 'bacno', 'contp', 
            'etymd', 'acqic', 'hour_range',"loctm_hour_of_day"]

# %%
from sklearn.preprocessing import LabelEncoder
for col in CATEGORY:
    try:
        le = LabelEncoder()
        le.fit(np.concatenate([df_train[col], df_test[col]]))
        df_train[col] = le.transform(df_train[col])
        df_test[col] = le.transform(df_test[col])
    except:
        df_train[col].cat.add_categories('NULL', inplace = True)
        df_test[col].cat.add_categories('NULL', inplace = True)
        le = LabelEncoder()
        le.fit(np.concatenate([df_train[col].fillna('NULL'), df_test[col].fillna('NULL')]))
        df_train[col] = le.transform(df_train[col].fillna('NULL'))
        df_test[col] = le.transform(df_test[col].fillna('NULL'))

# %%
df_train
# Out:
#          acqic   bacno    cano    conam  contp  csmcu  ecfg  etymd  flbmk  \
# 0         6862  112785   37846   513.80      5      0     0      0      0
# 1            0  133951   45476   465.62      5      0     0      2      0
# 2         6862   15350  187354   513.80      5      0     0      0      0
# 3         6697  156492   29812  1016.11      5     62     0      5      0
# 4         5959  105534   80881   713.66      5     62     0      4      0
# ...        ...     ...     ...      ...    ...    ...   ...    ...    ...
# 1521782   6305   90635   15111   578.38      5     75     1      8      1
# 1521783   3214  144503  115625   435.32      5     75     1      8      1
# 1521784   6750  161473   93103     1.38      5     75     1      8      1
# 1521785   6016   45215  196436     1.38      5     75     1      2      1
# 1521786   6697   48520  175523   406.59      5     75     0      5      1
#
#          flg_3dsmk  ...  mchno  ovrlt  scity  stocn  stscd    txkey  \
# 0                0  ...  59034      0      0    102      0   516056
# 1                0  ...      0      0   5795    102      0     4376
# 2                0  ...  59034      0      0    102      0   483434
# 3                0  ...  50185      0   3267    102      0  1407164
# 4                0  ...  93290      0   5795    102      0  1051004
# ...            ...  ...    ...    ...    ...    ...    ...      ...
# 1521782          1  ...  38034      0   5795    102      0  1478280
# 1521783          1  ...  89666      0   1450    102      0   661087
# 1521784          1  ...  78823      0   5795    102      0   167073
# 1521785          1  ...  78823      0   5795    102      0   338215
# 1521786          1  ...  69240      0   2300    102      0  1055258
#
#          loctm_hour_of_day  loctm_minute_of_hour  loctm_second_of_min  \
# 0                       17                    26                   52
# 1                       10                    51                   14
# 2                       15                    24                   58
# 3                       17                    29                   46
# 4                       18                    21                   29
# ...                    ...                   ...                  ...
# 1521782                 19                    16                   42
# 1521783                 10                    23                   38
# 1521784                 23                    46                   18
# 1521785                 21                    52                   18
# 1521786                 16                    36                    3
#
#          hour_range
# 0                 0
# 1                 2
# 2                 0
# 3                 0
# 4                 3
# ...             ...
# 1521782           3
# 1521783           2
# 1521784           3
# 1521785           3
# 1521786           0
#
# [1521787 rows x 27 columns]

# %%
from xgboost import XGBClassifier

# %%
def xgb_f1_score(y_pred, y_true):
    """evaluation metric"""
    y_hat = np.round(y_pred)
    y_true = y_true.get_label()
    #print ('f1-score', f1_score(y_true, y_hat))
    return 'f1-score-error', 1-f1_score(y_true, y_hat) # error

clf = XGBClassifier(
    n_jobs = 1,
    max_depth=3,
    learning_rate=0.05,
    n_estimators=10000,
    silent=True,
    objective='binary:logistic',
    booster='gbtree',
    gamma=0, 
    min_child_weight=1, 
    max_delta_step=0, 
    subsample=0.8, 
    colsample_bytree=1, 
    colsample_bylevel=1, 
    colsample_bynode=0.8, 
    reg_alpha=0, 
    reg_lambda=1e-05,
    random_state=1030,
    scale_pos_weight=args.SCALE_POS_WEIGHT
    )
clf
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=0.8, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=10000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=1030,
#               reg_alpha=0, reg_lambda=1e-05, scale_pos_weight=3, seed=None,
#               silent=True, subsample=0.8, verbosity=1)

# %%
feats = [f for f in df_train.columns if f not in ["fraud_ind"]]
train_x, train_y = df_train[feats], df_train['fraud_ind']
valid_x, valid_y = df_train[feats], df_train['fraud_ind']

# %%
clf.fit(train_x, 
        train_y, 
        eval_set=[(train_x, train_y), (valid_x, valid_y)], 
        eval_metric= xgb_f1_score, 
        verbose= True, 
        early_stopping_rounds= 100, 
        #categorical_feature='auto'
       ) # early_stopping_rounds= 200
# Out:
# f1-score 0.3894379614193855
# f1-score 0.3894379614193855
# [0]	validation_0-error:0.013478	validation_1-error:0.013478	validation_0-f1-score-error:0.610562	validation_1-f1-score-error:0.610562
# Multiple eval metrics have been passed: 'validation_1-f1-score-error' will be used for early stopping.
#
# Will train until validation_1-f1-score-error hasn't improved in 100 rounds.
# f1-score 0.3704486184927211
# f1-score 0.3704486184927211
# [1]	validation_0-error:0.012532	validation_1-error:0.012532	validation_0-f1-score-error:0.629551	validation_1-f1-score-error:0.629551
# f1-score 0.39025644321614505
# f1-score 0.39025644321614505
# [2]	validation_0-error:0.012468	validation_1-error:0.012468	validation_0-f1-score-error:0.609744	validation_1-f1-score-error:0.609744
# f1-score 0.4366318719554628
# f1-score 0.4366318719554628
# [3]	validation_0-error:0.013299	validation_1-error:0.013299	validation_0-f1-score-error:0.563368	validation_1-f1-score-error:0.563368
# f1-score 0.39867764391747995
# f1-score 0.39867764391747995
# [4]	validation_0-error:0.012431	validation_1-error:0.012431	validation_0-f1-score-error:0.601322	validation_1-f1-score-error:0.601322
# f1-score 0.38998716302952513
# f1-score 0.38998716302952513
# [5]	validation_0-error:0.012491	validation_1-error:0.012491	validation_0-f1-score-error:0.610013	validation_1-f1-score-error:0.610013
# f1-score 0.3896078810121692
# f1-score 0.3896078810121692
# [6]	validation_0-error:0.012459	validation_1-error:0.012459	validation_0-f1-score-error:0.610392	validation_1-f1-score-error:0.610392
# f1-score 0.39368712031114395
# f1-score 0.39368712031114395
# [7]	validation_0-error:0.012395	validation_1-error:0.012395	validation_0-f1-score-error:0.606313	validation_1-f1-score-error:0.606313
# f1-score 0.39416898436750747
# f1-score 0.39416898436750747
# [8]	validation_0-error:0.012453	validation_1-error:0.012453	validation_0-f1-score-error:0.605831	validation_1-f1-score-error:0.605831
# f1-score 0.393598255235896
# f1-score 0.393598255235896
# [9]	validation_0-error:0.012424	validation_1-error:0.012424	validation_0-f1-score-error:0.606402	validation_1-f1-score-error:0.606402
# f1-score 0.3961914499329031
# f1-score 0.3961914499329031
# [10]	validation_0-error:0.012418	validation_1-error:0.012418	validation_0-f1-score-error:0.603809	validation_1-f1-score-error:0.603809
# f1-score 0.39522682193358505
# f1-score 0.39522682193358505
# [11]	validation_0-error:0.012422	validation_1-error:0.012422	validation_0-f1-score-error:0.604773	validation_1-f1-score-error:0.604773
# f1-score 0.40459638764562106
# f1-score 0.40459638764562106
# [12]	validation_0-error:0.012326	validation_1-error:0.012326	validation_0-f1-score-error:0.595404	validation_1-f1-score-error:0.595404
# f1-score 0.40712773688035137
# f1-score 0.40712773688035137
# [13]	validation_0-error:0.012331	validation_1-error:0.012331	validation_0-f1-score-error:0.592872	validation_1-f1-score-error:0.592872
# f1-score 0.4163239679799089
# f1-score 0.4163239679799089
# [14]	validation_0-error:0.012218	validation_1-error:0.012218	validation_0-f1-score-error:0.583676	validation_1-f1-score-error:0.583676
# f1-score 0.39704801763521935
# f1-score 0.39704801763521935
# [15]	validation_0-error:0.012402	validation_1-error:0.012402	validation_0-f1-score-error:0.602952	validation_1-f1-score-error:0.602952
# f1-score 0.4026858452138493
# f1-score 0.4026858452138493
# [16]	validation_0-error:0.012334	validation_1-error:0.012334	validation_0-f1-score-error:0.597314	validation_1-f1-score-error:0.597314
# f1-score 0.40270511675385995
# f1-score 0.40270511675385995
# [17]	validation_0-error:0.012304	validation_1-error:0.012304	validation_0-f1-score-error:0.597295	validation_1-f1-score-error:0.597295
# f1-score 0.4027440970006382
# f1-score 0.4027440970006382
# [18]	validation_0-error:0.0123	validation_1-error:0.0123	validation_0-f1-score-error:0.597256	validation_1-f1-score-error:0.597256
# f1-score 0.403672649599898
# f1-score 0.403672649599898
# [19]	validation_0-error:0.012291	validation_1-error:0.012291	validation_0-f1-score-error:0.596327	validation_1-f1-score-error:0.596327
# f1-score 0.40173918603535924
# f1-score 0.40173918603535924
# [20]	validation_0-error:0.012297	validation_1-error:0.012297	validation_0-f1-score-error:0.598261	validation_1-f1-score-error:0.598261
# f1-score 0.39907772120280527
# f1-score 0.39907772120280527
# [21]	validation_0-error:0.012331	validation_1-error:0.012331	validation_0-f1-score-error:0.600922	validation_1-f1-score-error:0.600922
# f1-score 0.41035881830860915
# f1-score 0.41035881830860915
# [22]	validation_0-error:0.012224	validation_1-error:0.012224	validation_0-f1-score-error:0.589641	validation_1-f1-score-error:0.589641
# f1-score 0.41176097437198683
# f1-score 0.41176097437198683
# [23]	validation_0-error:0.012187	validation_1-error:0.012187	validation_0-f1-score-error:0.588239	validation_1-f1-score-error:0.588239
# f1-score 0.41275583055687765
# f1-score 0.41275583055687765
# [24]	validation_0-error:0.012161	validation_1-error:0.012161	validation_0-f1-score-error:0.587244	validation_1-f1-score-error:0.587244
# f1-score 0.4122269068608662
# f1-score 0.4122269068608662
# [25]	validation_0-error:0.012092	validation_1-error:0.012092	validation_0-f1-score-error:0.587773	validation_1-f1-score-error:0.587773
# f1-score 0.4119641714651312
# f1-score 0.4119641714651312
# [26]	validation_0-error:0.012079	validation_1-error:0.012079	validation_0-f1-score-error:0.588036	validation_1-f1-score-error:0.588036
# f1-score 0.41159346108320805
# f1-score 0.41159346108320805
# [27]	validation_0-error:0.012086	validation_1-error:0.012086	validation_0-f1-score-error:0.588407	validation_1-f1-score-error:0.588407
# f1-score 0.4128323108384458
# f1-score 0.4128323108384458
# [28]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1-score-error:0.587168	validation_1-f1-score-error:0.587168
# f1-score 0.4121868392388031
# f1-score 0.4121868392388031
# [29]	validation_0-error:0.012057	validation_1-error:0.012057	validation_0-f1-score-error:0.587813	validation_1-f1-score-error:0.587813
# f1-score 0.4141291884316473
# f1-score 0.4141291884316473
# [30]	validation_0-error:0.012087	validation_1-error:0.012087	validation_0-f1-score-error:0.585871	validation_1-f1-score-error:0.585871
# f1-score 0.41377327754176374
# f1-score 0.41377327754176374
# [31]	validation_0-error:0.01206	validation_1-error:0.01206	validation_0-f1-score-error:0.586227	validation_1-f1-score-error:0.586227
# f1-score 0.41390326496709473
# f1-score 0.41390326496709473
# [32]	validation_0-error:0.012056	validation_1-error:0.012056	validation_0-f1-score-error:0.586097	validation_1-f1-score-error:0.586097
# f1-score 0.41169500752553884
# f1-score 0.41169500752553884
# [33]	validation_0-error:0.012072	validation_1-error:0.012072	validation_0-f1-score-error:0.588305	validation_1-f1-score-error:0.588305
# f1-score 0.4120548296182424
# f1-score 0.4120548296182424
# [34]	validation_0-error:0.012063	validation_1-error:0.012063	validation_0-f1-score-error:0.587945	validation_1-f1-score-error:0.587945
# f1-score 0.4126598465473146
# f1-score 0.4126598465473146
# [35]	validation_0-error:0.012073	validation_1-error:0.012073	validation_0-f1-score-error:0.58734	validation_1-f1-score-error:0.58734
# f1-score 0.4078511998458029
# f1-score 0.4078511998458029
# [36]	validation_0-error:0.012113	validation_1-error:0.012113	validation_0-f1-score-error:0.592149	validation_1-f1-score-error:0.592149
# f1-score 0.40764208291788623
# f1-score 0.40764208291788623
# [37]	validation_0-error:0.012102	validation_1-error:0.012102	validation_0-f1-score-error:0.592358	validation_1-f1-score-error:0.592358
# f1-score 0.40719179183686605
# f1-score 0.40719179183686605
# [38]	validation_0-error:0.012111	validation_1-error:0.012111	validation_0-f1-score-error:0.592808	validation_1-f1-score-error:0.592808
# f1-score 0.4090135781465669
# f1-score 0.4090135781465669
# [39]	validation_0-error:0.012098	validation_1-error:0.012098	validation_0-f1-score-error:0.590986	validation_1-f1-score-error:0.590986
# f1-score 0.4102350871581641
# f1-score 0.4102350871581641
# [40]	validation_0-error:0.012117	validation_1-error:0.012117	validation_0-f1-score-error:0.589765	validation_1-f1-score-error:0.589765
# f1-score 0.41307464398356114
# f1-score 0.41307464398356114
# [41]	validation_0-error:0.012106	validation_1-error:0.012106	validation_0-f1-score-error:0.586925	validation_1-f1-score-error:0.586925
# f1-score 0.41589883713541337
# f1-score 0.41589883713541337
# [42]	validation_0-error:0.012081	validation_1-error:0.012081	validation_0-f1-score-error:0.584101	validation_1-f1-score-error:0.584101
# f1-score 0.4130372447191512
# f1-score 0.4130372447191512
# [43]	validation_0-error:0.012106	validation_1-error:0.012106	validation_0-f1-score-error:0.586963	validation_1-f1-score-error:0.586963
# f1-score 0.4127511419171432
# f1-score 0.4127511419171432
# [44]	validation_0-error:0.012081	validation_1-error:0.012081	validation_0-f1-score-error:0.587249	validation_1-f1-score-error:0.587249
# f1-score 0.4138084916486039
# f1-score 0.4138084916486039
# [45]	validation_0-error:0.012084	validation_1-error:0.012084	validation_0-f1-score-error:0.586192	validation_1-f1-score-error:0.586192
# f1-score 0.41586553765836887
# f1-score 0.41586553765836887
# [46]	validation_0-error:0.012058	validation_1-error:0.012058	validation_0-f1-score-error:0.584134	validation_1-f1-score-error:0.584134
# f1-score 0.4164360907038132
# f1-score 0.4164360907038132
# [47]	validation_0-error:0.012058	validation_1-error:0.012058	validation_0-f1-score-error:0.583564	validation_1-f1-score-error:0.583564
# f1-score 0.41687045447327464
# f1-score 0.41687045447327464
# [48]	validation_0-error:0.012065	validation_1-error:0.012065	validation_0-f1-score-error:0.58313	validation_1-f1-score-error:0.58313
# f1-score 0.4184269521012914
# f1-score 0.4184269521012914
# [49]	validation_0-error:0.012104	validation_1-error:0.012104	validation_0-f1-score-error:0.581573	validation_1-f1-score-error:0.581573
# f1-score 0.4195848318505899
# f1-score 0.4195848318505899
# [50]	validation_0-error:0.01209	validation_1-error:0.01209	validation_0-f1-score-error:0.580415	validation_1-f1-score-error:0.580415
# f1-score 0.4195883784894565
# f1-score 0.4195883784894565
# [51]	validation_0-error:0.012064	validation_1-error:0.012064	validation_0-f1-score-error:0.580412	validation_1-f1-score-error:0.580412
# f1-score 0.4198769522006625
# f1-score 0.4198769522006625
# [52]	validation_0-error:0.012083	validation_1-error:0.012083	validation_0-f1-score-error:0.580123	validation_1-f1-score-error:0.580123
# f1-score 0.42411525211399936
# f1-score 0.42411525211399936
# [53]	validation_0-error:0.012083	validation_1-error:0.012083	validation_0-f1-score-error:0.575885	validation_1-f1-score-error:0.575885
# f1-score 0.42008730881567785
# f1-score 0.42008730881567785
# [54]	validation_0-error:0.012134	validation_1-error:0.012134	validation_0-f1-score-error:0.579913	validation_1-f1-score-error:0.579913
# f1-score 0.4198842912841152
# f1-score 0.4198842912841152
# [55]	validation_0-error:0.012124	validation_1-error:0.012124	validation_0-f1-score-error:0.580116	validation_1-f1-score-error:0.580116
# f1-score 0.4232396352354987
# f1-score 0.4232396352354987
# [56]	validation_0-error:0.012094	validation_1-error:0.012094	validation_0-f1-score-error:0.57676	validation_1-f1-score-error:0.57676
# f1-score 0.4249789134984849
# f1-score 0.4249789134984849
# [57]	validation_0-error:0.012096	validation_1-error:0.012096	validation_0-f1-score-error:0.575021	validation_1-f1-score-error:0.575021
# f1-score 0.4250546704154951
# f1-score 0.4250546704154951
# [58]	validation_0-error:0.012094	validation_1-error:0.012094	validation_0-f1-score-error:0.574945	validation_1-f1-score-error:0.574945
# f1-score 0.4266367097297634
# f1-score 0.4266367097297634
# [59]	validation_0-error:0.012074	validation_1-error:0.012074	validation_0-f1-score-error:0.573363	validation_1-f1-score-error:0.573363
# f1-score 0.426676653247199
# f1-score 0.426676653247199
# [60]	validation_0-error:0.012072	validation_1-error:0.012072	validation_0-f1-score-error:0.573323	validation_1-f1-score-error:0.573323
# f1-score 0.4266541822721598
# f1-score 0.4266541822721598
# [61]	validation_0-error:0.012071	validation_1-error:0.012071	validation_0-f1-score-error:0.573346	validation_1-f1-score-error:0.573346
# f1-score 0.4261189837068481
# f1-score 0.4261189837068481
# [62]	validation_0-error:0.012082	validation_1-error:0.012082	validation_0-f1-score-error:0.573881	validation_1-f1-score-error:0.573881
# f1-score 0.4267223902941084
# f1-score 0.4267223902941084
# [63]	validation_0-error:0.012079	validation_1-error:0.012079	validation_0-f1-score-error:0.573278	validation_1-f1-score-error:0.573278
# f1-score 0.4268022584770877
# f1-score 0.4268022584770877
# [64]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1-score-error:0.573198	validation_1-f1-score-error:0.573198
# f1-score 0.42513921041106173
# f1-score 0.42513921041106173
# [65]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1-score-error:0.574861	validation_1-f1-score-error:0.574861
# f1-score 0.4267490097002588
# f1-score 0.4267490097002588
# [66]	validation_0-error:0.012077	validation_1-error:0.012077	validation_0-f1-score-error:0.573251	validation_1-f1-score-error:0.573251
# f1-score 0.42671741436326205
# f1-score 0.42671741436326205
# [67]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1-score-error:0.573283	validation_1-f1-score-error:0.573283
# f1-score 0.42569552985307907
# f1-score 0.42569552985307907
# [68]	validation_0-error:0.012073	validation_1-error:0.012073	validation_0-f1-score-error:0.574304	validation_1-f1-score-error:0.574304
# f1-score 0.4274251459614724
# f1-score 0.4274251459614724
# [69]	validation_0-error:0.012051	validation_1-error:0.012051	validation_0-f1-score-error:0.572575	validation_1-f1-score-error:0.572575
# f1-score 0.42982674809921473
# f1-score 0.42982674809921473
# [70]	validation_0-error:0.012024	validation_1-error:0.012024	validation_0-f1-score-error:0.570173	validation_1-f1-score-error:0.570173
# f1-score 0.4299572662902773
# f1-score 0.4299572662902773
# [71]	validation_0-error:0.012009	validation_1-error:0.012009	validation_0-f1-score-error:0.570043	validation_1-f1-score-error:0.570043
# f1-score 0.4296139212873448
# f1-score 0.4296139212873448
# [72]	validation_0-error:0.012019	validation_1-error:0.012019	validation_0-f1-score-error:0.570386	validation_1-f1-score-error:0.570386
# f1-score 0.4314885139762186
# f1-score 0.4314885139762186
# [73]	validation_0-error:0.012002	validation_1-error:0.012002	validation_0-f1-score-error:0.568511	validation_1-f1-score-error:0.568511
# f1-score 0.4378756588478254
# f1-score 0.4378756588478254
# [74]	validation_0-error:0.011984	validation_1-error:0.011984	validation_0-f1-score-error:0.562124	validation_1-f1-score-error:0.562124
# f1-score 0.442794920557021
# f1-score 0.442794920557021
# [75]	validation_0-error:0.011937	validation_1-error:0.011937	validation_0-f1-score-error:0.557205	validation_1-f1-score-error:0.557205
# f1-score 0.44306862414564624
# f1-score 0.44306862414564624
# [76]	validation_0-error:0.011941	validation_1-error:0.011941	validation_0-f1-score-error:0.556931	validation_1-f1-score-error:0.556931
# f1-score 0.4421897989210397
# f1-score 0.4421897989210397
# [77]	validation_0-error:0.011958	validation_1-error:0.011958	validation_0-f1-score-error:0.55781	validation_1-f1-score-error:0.55781
# f1-score 0.43959958238653807
# f1-score 0.43959958238653807
# [78]	validation_0-error:0.011992	validation_1-error:0.011992	validation_0-f1-score-error:0.5604	validation_1-f1-score-error:0.5604
# f1-score 0.443934807204232
# f1-score 0.443934807204232
# [79]	validation_0-error:0.01195	validation_1-error:0.01195	validation_0-f1-score-error:0.556065	validation_1-f1-score-error:0.556065
# f1-score 0.4453576864535769
# f1-score 0.4453576864535769
# [80]	validation_0-error:0.011973	validation_1-error:0.011973	validation_0-f1-score-error:0.554642	validation_1-f1-score-error:0.554642
# f1-score 0.4421181138409889
# f1-score 0.4421181138409889
# [81]	validation_0-error:0.012012	validation_1-error:0.012012	validation_0-f1-score-error:0.557882	validation_1-f1-score-error:0.557882
# f1-score 0.44290594119799925
# f1-score 0.44290594119799925
# [82]	validation_0-error:0.012003	validation_1-error:0.012003	validation_0-f1-score-error:0.557094	validation_1-f1-score-error:0.557094
# f1-score 0.44327884849963406
# f1-score 0.44327884849963406
# [83]	validation_0-error:0.011996	validation_1-error:0.011996	validation_0-f1-score-error:0.556721	validation_1-f1-score-error:0.556721
# f1-score 0.44750378214826025
# f1-score 0.44750378214826025
# [84]	validation_0-error:0.011999	validation_1-error:0.011999	validation_0-f1-score-error:0.552496	validation_1-f1-score-error:0.552496
# f1-score 0.4476294146105467
# f1-score 0.4476294146105467
# [85]	validation_0-error:0.012004	validation_1-error:0.012004	validation_0-f1-score-error:0.552371	validation_1-f1-score-error:0.552371
# f1-score 0.4511890050935833
# f1-score 0.4511890050935833
# [86]	validation_0-error:0.011966	validation_1-error:0.011966	validation_0-f1-score-error:0.548811	validation_1-f1-score-error:0.548811
# f1-score 0.4514321857775368
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-111-127fdb6e2f9f> in <module>
#       4         eval_metric= xgb_f1_score,
#       5         verbose= True,
# ----> 6         early_stopping_rounds= 100,
#       7         #categorical_feature='auto'
#       8        ) # early_stopping_rounds= 200
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      82         # check evaluation result.
#      83         if evals:
# ---> 84             bst_eval_set = bst.eval_set(evals, i, feval)
#      85             if isinstance(bst_eval_set, STRING_TYPES):
#      86                 msg = bst_eval_set
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/xgboost/core.py in eval_set(self, evals, iteration, feval)
#    1174         if feval is not None:
#    1175             for dmat, evname in evals:
# -> 1176                 feval_ret = feval(self.predict(dmat), dmat)
#    1177                 if isinstance(feval_ret, list):
#    1178                     for name, val in feval_ret:
#
# <ipython-input-109-1f9dfffe9b7f> in xgb_f1_score(y_pred, y_true)
#       3     y_hat = np.round(y_pred)
#       4     y_true = y_true.get_label()
# ----> 5     print ('f1-score', f1_score(y_true, y_hat))
#       6     return 'f1-score-error', 1-f1_score(y_true, y_hat) # error
#       7
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/sklearn/metrics/classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#    1057     return fbeta_score(y_true, y_pred, 1, labels=labels,
#    1058                        pos_label=pos_label, average=average,
# -> 1059                        sample_weight=sample_weight)
#    1060
#    1061
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/sklearn/metrics/classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight)
#    1180                                                  average=average,
#    1181                                                  warn_for=('f-score',),
# -> 1182                                                  sample_weight=sample_weight)
#    1183     return f
#    1184
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/sklearn/metrics/classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#    1413         raise ValueError("beta should be >0 in the F-beta score")
#    1414     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# -> 1415                                     pos_label)
#    1416
#    1417     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1237                          str(average_options))
#    1238
# -> 1239     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1240     present_labels = unique_labels(y_true, y_pred)
#    1241     if average == 'binary':
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
# ---> 73     type_pred = type_of_target(y_pred)
#      74
#      75     y_type = {type_true, type_pred}
#
# ~/.pyenv/versions/3.6.5/envs/fraud/lib/python3.6/site-packages/sklearn/utils/multiclass.py in type_of_target(y)
#     280
#     281     # check float and contains non-integer float values
# --> 282     if y.dtype.kind == 'f' and np.any(y != y.astype(int)):
#     283         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
#     284         _assert_all_finite(y)
#
# KeyboardInterrupt:
