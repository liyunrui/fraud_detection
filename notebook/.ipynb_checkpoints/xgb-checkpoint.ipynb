# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
import lightgbm as lgb
from sklearn.metrics import f1_score
import numpy as np
from contextlib import contextmanager
import time
import sys
import gc 
sys.path.append("../fraud_detection/src/")
from util import s_to_time_format, string_to_datetime,hour_to_range

CATEGORY = ['ecfg', 'flbmk', 'flg_3dsmk', 'insfg', 'ovrlt', 'scity', 'csmcu', 'cano', 'mchno', 'hcefg', 'bacno', 'contp', 'etymd', 'acqic']

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))
    
def main(args):
    with timer("Process train/test application"):
        #-------------------------
        # load dataset
        #-------------------------
        df_train = pd.read_csv(args.train_file)
        df_test = pd.read_csv(args.test_file)

        #-------------------------
        # pre-processing
        #-------------------------

        for cat in CATEGORY:
            df_train[cat] = df_train[cat].astype('category')#.cat.codes
            df_test[cat] = df_test[cat].astype('category')
            
        print("Train application df shape:", df_train.shape)
        print("Test application df shape:", df_test.shape)
        
        for df in [df_train, df_test]:
            # pre-processing
            df["loctm_"] = df.loctm.astype(int).astype(str)
            df.loctm_ = df.loctm_.apply(s_to_time_format).apply(string_to_datetime)
            # time-related feature
            df["loctm_hour_of_day"] = df.loctm_.apply(lambda x: x.hour).astype('category')
            df["loctm_minute_of_hour"] = df.loctm_.apply(lambda x: x.minute)
            df["loctm_second_of_min"] = df.loctm_.apply(lambda x: x.second)
            #df["loctm_absolute_time"] = [h*60+m for h,m in zip(df.loctm_hour_of_day,df.loctm_minute_of_hour)]
            df["hour_range"] = df.loctm_.apply(lambda x: hour_to_range(x.hour)).astype("category")
            # removed the columns no need
            df.drop(columns = ["loctm_"], axis = 1, inplace = True)
    return df_train, df_test

# %%
args = {
 "train_file":"/data/yunrui_li/fraud/dataset/train.csv",
 "test_file":"/data/yunrui_li/fraud/dataset/test.csv",
 "result_path":"/data/yunrui_li/fraud/fraud_detection/result/submission.csv",
 "feature_selection":False,
 "feature_importance_plot": True,
 "SEED": 1030,
 "NUM_FOLDS": 2, # 5
 "CPU_USE_RATE":1.0,
 "STRATIFIED": True,
 "TEST_NULL_HYPO":False,
 "NUM_LEAVES":31,
 "COLSAMPLE_BYTREE":1.0,
 "SUBSAMPLE": 1.0,
 "SUBSAMPLE_FREQ": 0,
 "MAX_DEPTH": -1,
 "REG_ALPHA": 0.0,
 "REG_LAMBDA": 0.0,
 "MIN_SPLIT_GAIN": 0.0,
 "MIN_CHILD_WEIGHT": 0.001,
 "MAX_BIN": 255,
 "SCALE_POS_WEIGHT": 3
    
}
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self
args = AttrDict(args)
args
# Out:
# {'train_file': '/data/yunrui_li/fraud/dataset/train.csv',
#  'test_file': '/data/yunrui_li/fraud/dataset/test.csv',
#  'result_path': '/data/yunrui_li/fraud/fraud_detection/result/submission.csv',
#  'feature_selection': False,
#  'feature_importance_plot': True,
#  'SEED': 1030,
#  'NUM_FOLDS': 2,
#  'CPU_USE_RATE': 1.0,
#  'STRATIFIED': True,
#  'TEST_NULL_HYPO': False,
#  'NUM_LEAVES': 31,
#  'COLSAMPLE_BYTREE': 1.0,
#  'SUBSAMPLE': 1.0,
#  'SUBSAMPLE_FREQ': 0,
#  'MAX_DEPTH': -1,
#  'REG_ALPHA': 0.0,
#  'REG_LAMBDA': 0.0,
#  'MIN_SPLIT_GAIN': 0.0,
#  'MIN_CHILD_WEIGHT': 0.001,
#  'MAX_BIN': 255,
#  'SCALE_POS_WEIGHT': 3}

# %%
df_train, df_test = main(args)
# Out:
# Train application df shape: (1521787, 23)
# Test application df shape: (421665, 22)
# Process train/test application - done in 79s

# %%
# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df_train, df_test, nan_as_category = True):
    df = pd.concat([df_train, df_test], axis = 0)
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
df = pd.concat([df_train, df_test], axis = 0)

# %%
original_columns = list(df.columns)
# categorical_columns = [col for col in df.columns if df[col].dtype == 'object']

# %%
CATEGORY = ['ecfg', 'flbmk', 'flg_3dsmk', 'insfg', 
            'ovrlt', 'scity', 'csmcu', 'cano', 
            'mchno', 'hcefg', 'bacno', 'contp', 
            'etymd', 'acqic', 'hour_range',"loctm_hour_of_day"]

# %%
from sklearn.preprocessing import LabelEncoder
for col in CATEGORY:
    try:
        le = LabelEncoder()
        le.fit(np.concatenate([df_train[col], df_test[col]]))
        df_train[col] = le.transform(df_train[col])
        df_test[col] = le.transform(df_test[col])
    except:
        df_train[col].cat.add_categories('NULL', inplace = True)
        df_test[col].cat.add_categories('NULL', inplace = True)
        le = LabelEncoder()
        le.fit(np.concatenate([df_train[col].fillna('NULL'), df_test[col].fillna('NULL')]))
        df_train[col] = le.transform(df_train[col].fillna('NULL'))
        df_test[col] = le.transform(df_test[col].fillna('NULL'))

# %%
df_train
# Out:
#          acqic   bacno    cano    conam  contp  csmcu  ecfg  etymd  flbmk  \
# 0         6862  112785   37846   513.80      5      0     0      0      0
# 1            0  133951   45476   465.62      5      0     0      2      0
# 2         6862   15350  187354   513.80      5      0     0      0      0
# 3         6697  156492   29812  1016.11      5     62     0      5      0
# 4         5959  105534   80881   713.66      5     62     0      4      0
# ...        ...     ...     ...      ...    ...    ...   ...    ...    ...
# 1521782   6305   90635   15111   578.38      5     75     1      8      1
# 1521783   3214  144503  115625   435.32      5     75     1      8      1
# 1521784   6750  161473   93103     1.38      5     75     1      8      1
# 1521785   6016   45215  196436     1.38      5     75     1      2      1
# 1521786   6697   48520  175523   406.59      5     75     0      5      1
#
#          flg_3dsmk  ...  mchno  ovrlt  scity  stocn  stscd    txkey  \
# 0                0  ...  59034      0      0    102      0   516056
# 1                0  ...      0      0   5795    102      0     4376
# 2                0  ...  59034      0      0    102      0   483434
# 3                0  ...  50185      0   3267    102      0  1407164
# 4                0  ...  93290      0   5795    102      0  1051004
# ...            ...  ...    ...    ...    ...    ...    ...      ...
# 1521782          1  ...  38034      0   5795    102      0  1478280
# 1521783          1  ...  89666      0   1450    102      0   661087
# 1521784          1  ...  78823      0   5795    102      0   167073
# 1521785          1  ...  78823      0   5795    102      0   338215
# 1521786          1  ...  69240      0   2300    102      0  1055258
#
#          loctm_hour_of_day  loctm_minute_of_hour  loctm_second_of_min  \
# 0                       17                    26                   52
# 1                       10                    51                   14
# 2                       15                    24                   58
# 3                       17                    29                   46
# 4                       18                    21                   29
# ...                    ...                   ...                  ...
# 1521782                 19                    16                   42
# 1521783                 10                    23                   38
# 1521784                 23                    46                   18
# 1521785                 21                    52                   18
# 1521786                 16                    36                    3
#
#          hour_range
# 0                 0
# 1                 2
# 2                 0
# 3                 0
# 4                 3
# ...             ...
# 1521782           3
# 1521783           2
# 1521784           3
# 1521785           3
# 1521786           0
#
# [1521787 rows x 27 columns]

# %%
from xgboost import XGBClassifier

# %%
def xgb_f1_score(y_pred, y_true):
    """evaluation metric"""
    y_hat = np.round(y_pred)
    y_true = y_true.get_label()
    return 'f1', 1-f1_score(y_true, y_hat)

clf = XGBClassifier(
    n_jobs = 1,
    max_depth=3,
    learning_rate=0.05,
    n_estimators=10000,
    silent=True,
    objective='binary:logistic',
    booster='gbtree',
    gamma=0, 
    min_child_weight=1, 
    max_delta_step=0, 
    subsample=0.8, 
    colsample_bytree=1, 
    colsample_bylevel=1, 
    colsample_bynode=0.8, 
    reg_alpha=0, 
    reg_lambda=1e-05,
    random_state=1030,
    scale_pos_weight=args.SCALE_POS_WEIGHT
    )
clf
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=0.8, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=10000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=1030,
#               reg_alpha=0, reg_lambda=1e-05, scale_pos_weight=3, seed=None,
#               silent=True, subsample=0.8, verbosity=1)

# %%
feats = [f for f in df_train.columns if f not in ["fraud_ind"]]
train_x, train_y = df_train[feats], df_train['fraud_ind']
valid_x, valid_y = df_train[feats], df_train['fraud_ind']

# %%
clf.fit(train_x, 
        train_y, 
        eval_set=[(train_x, train_y), (valid_x, valid_y)], 
        eval_metric= xgb_f1_score, 
        verbose= True, 
        early_stopping_rounds= 100, 
        #categorical_feature='auto'
       ) # early_stopping_rounds= 200
# Out:
# [0]	validation_0-error:0.013478	validation_1-error:0.013478	validation_0-f1:0.389438	validation_1-f1:0.389438
# Multiple eval metrics have been passed: 'validation_1-f1' will be used for early stopping.
#
# Will train until validation_1-f1 hasn't improved in 100 rounds.
# [1]	validation_0-error:0.012532	validation_1-error:0.012532	validation_0-f1:0.370449	validation_1-f1:0.370449
# [2]	validation_0-error:0.012468	validation_1-error:0.012468	validation_0-f1:0.390256	validation_1-f1:0.390256
# [3]	validation_0-error:0.013299	validation_1-error:0.013299	validation_0-f1:0.436632	validation_1-f1:0.436632
# [4]	validation_0-error:0.012431	validation_1-error:0.012431	validation_0-f1:0.398678	validation_1-f1:0.398678
# [5]	validation_0-error:0.012491	validation_1-error:0.012491	validation_0-f1:0.389987	validation_1-f1:0.389987
# [6]	validation_0-error:0.012459	validation_1-error:0.012459	validation_0-f1:0.389608	validation_1-f1:0.389608
# [7]	validation_0-error:0.012395	validation_1-error:0.012395	validation_0-f1:0.393687	validation_1-f1:0.393687
# [8]	validation_0-error:0.012453	validation_1-error:0.012453	validation_0-f1:0.394169	validation_1-f1:0.394169
# [9]	validation_0-error:0.012424	validation_1-error:0.012424	validation_0-f1:0.393598	validation_1-f1:0.393598
# [10]	validation_0-error:0.012418	validation_1-error:0.012418	validation_0-f1:0.396191	validation_1-f1:0.396191
# [11]	validation_0-error:0.012422	validation_1-error:0.012422	validation_0-f1:0.395227	validation_1-f1:0.395227
# [12]	validation_0-error:0.012326	validation_1-error:0.012326	validation_0-f1:0.404596	validation_1-f1:0.404596
# [13]	validation_0-error:0.012331	validation_1-error:0.012331	validation_0-f1:0.407128	validation_1-f1:0.407128
# [14]	validation_0-error:0.012218	validation_1-error:0.012218	validation_0-f1:0.416324	validation_1-f1:0.416324
# [15]	validation_0-error:0.012402	validation_1-error:0.012402	validation_0-f1:0.397048	validation_1-f1:0.397048
# [16]	validation_0-error:0.012334	validation_1-error:0.012334	validation_0-f1:0.402686	validation_1-f1:0.402686
# [17]	validation_0-error:0.012304	validation_1-error:0.012304	validation_0-f1:0.402705	validation_1-f1:0.402705
# [18]	validation_0-error:0.0123	validation_1-error:0.0123	validation_0-f1:0.402744	validation_1-f1:0.402744
# [19]	validation_0-error:0.012291	validation_1-error:0.012291	validation_0-f1:0.403673	validation_1-f1:0.403673
# [20]	validation_0-error:0.012297	validation_1-error:0.012297	validation_0-f1:0.401739	validation_1-f1:0.401739
# [21]	validation_0-error:0.012331	validation_1-error:0.012331	validation_0-f1:0.399078	validation_1-f1:0.399078
# [22]	validation_0-error:0.012224	validation_1-error:0.012224	validation_0-f1:0.410359	validation_1-f1:0.410359
# [23]	validation_0-error:0.012187	validation_1-error:0.012187	validation_0-f1:0.411761	validation_1-f1:0.411761
# [24]	validation_0-error:0.012161	validation_1-error:0.012161	validation_0-f1:0.412756	validation_1-f1:0.412756
# [25]	validation_0-error:0.012092	validation_1-error:0.012092	validation_0-f1:0.412227	validation_1-f1:0.412227
# [26]	validation_0-error:0.012079	validation_1-error:0.012079	validation_0-f1:0.411964	validation_1-f1:0.411964
# [27]	validation_0-error:0.012086	validation_1-error:0.012086	validation_0-f1:0.411593	validation_1-f1:0.411593
# [28]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1:0.412832	validation_1-f1:0.412832
# [29]	validation_0-error:0.012057	validation_1-error:0.012057	validation_0-f1:0.412187	validation_1-f1:0.412187
# [30]	validation_0-error:0.012087	validation_1-error:0.012087	validation_0-f1:0.414129	validation_1-f1:0.414129
# [31]	validation_0-error:0.01206	validation_1-error:0.01206	validation_0-f1:0.413773	validation_1-f1:0.413773
# [32]	validation_0-error:0.012056	validation_1-error:0.012056	validation_0-f1:0.413903	validation_1-f1:0.413903
# [33]	validation_0-error:0.012072	validation_1-error:0.012072	validation_0-f1:0.411695	validation_1-f1:0.411695
# [34]	validation_0-error:0.012063	validation_1-error:0.012063	validation_0-f1:0.412055	validation_1-f1:0.412055
# [35]	validation_0-error:0.012073	validation_1-error:0.012073	validation_0-f1:0.41266	validation_1-f1:0.41266
# [36]	validation_0-error:0.012113	validation_1-error:0.012113	validation_0-f1:0.407851	validation_1-f1:0.407851
# [37]	validation_0-error:0.012102	validation_1-error:0.012102	validation_0-f1:0.407642	validation_1-f1:0.407642
# [38]	validation_0-error:0.012111	validation_1-error:0.012111	validation_0-f1:0.407192	validation_1-f1:0.407192
# [39]	validation_0-error:0.012098	validation_1-error:0.012098	validation_0-f1:0.409014	validation_1-f1:0.409014
# [40]	validation_0-error:0.012117	validation_1-error:0.012117	validation_0-f1:0.410235	validation_1-f1:0.410235
# [41]	validation_0-error:0.012106	validation_1-error:0.012106	validation_0-f1:0.413075	validation_1-f1:0.413075
# [42]	validation_0-error:0.012081	validation_1-error:0.012081	validation_0-f1:0.415899	validation_1-f1:0.415899
# [43]	validation_0-error:0.012106	validation_1-error:0.012106	validation_0-f1:0.413037	validation_1-f1:0.413037
# [44]	validation_0-error:0.012081	validation_1-error:0.012081	validation_0-f1:0.412751	validation_1-f1:0.412751
# [45]	validation_0-error:0.012084	validation_1-error:0.012084	validation_0-f1:0.413808	validation_1-f1:0.413808
# [46]	validation_0-error:0.012058	validation_1-error:0.012058	validation_0-f1:0.415866	validation_1-f1:0.415866
# [47]	validation_0-error:0.012058	validation_1-error:0.012058	validation_0-f1:0.416436	validation_1-f1:0.416436
# [48]	validation_0-error:0.012065	validation_1-error:0.012065	validation_0-f1:0.41687	validation_1-f1:0.41687
# [49]	validation_0-error:0.012104	validation_1-error:0.012104	validation_0-f1:0.418427	validation_1-f1:0.418427
# [50]	validation_0-error:0.01209	validation_1-error:0.01209	validation_0-f1:0.419585	validation_1-f1:0.419585
# [51]	validation_0-error:0.012064	validation_1-error:0.012064	validation_0-f1:0.419588	validation_1-f1:0.419588
# [52]	validation_0-error:0.012083	validation_1-error:0.012083	validation_0-f1:0.419877	validation_1-f1:0.419877
# [53]	validation_0-error:0.012083	validation_1-error:0.012083	validation_0-f1:0.424115	validation_1-f1:0.424115
# [54]	validation_0-error:0.012134	validation_1-error:0.012134	validation_0-f1:0.420087	validation_1-f1:0.420087
# [55]	validation_0-error:0.012124	validation_1-error:0.012124	validation_0-f1:0.419884	validation_1-f1:0.419884
# [56]	validation_0-error:0.012094	validation_1-error:0.012094	validation_0-f1:0.42324	validation_1-f1:0.42324
# [57]	validation_0-error:0.012096	validation_1-error:0.012096	validation_0-f1:0.424979	validation_1-f1:0.424979
# [58]	validation_0-error:0.012094	validation_1-error:0.012094	validation_0-f1:0.425055	validation_1-f1:0.425055
# [59]	validation_0-error:0.012074	validation_1-error:0.012074	validation_0-f1:0.426637	validation_1-f1:0.426637
# [60]	validation_0-error:0.012072	validation_1-error:0.012072	validation_0-f1:0.426677	validation_1-f1:0.426677
# [61]	validation_0-error:0.012071	validation_1-error:0.012071	validation_0-f1:0.426654	validation_1-f1:0.426654
# [62]	validation_0-error:0.012082	validation_1-error:0.012082	validation_0-f1:0.426119	validation_1-f1:0.426119
# [63]	validation_0-error:0.012079	validation_1-error:0.012079	validation_0-f1:0.426722	validation_1-f1:0.426722
# [64]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1:0.426802	validation_1-f1:0.426802
# [65]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1:0.425139	validation_1-f1:0.425139
# [66]	validation_0-error:0.012077	validation_1-error:0.012077	validation_0-f1:0.426749	validation_1-f1:0.426749
# [67]	validation_0-error:0.012075	validation_1-error:0.012075	validation_0-f1:0.426717	validation_1-f1:0.426717
# [68]	validation_0-error:0.012073	validation_1-error:0.012073	validation_0-f1:0.425696	validation_1-f1:0.425696
# [69]	validation_0-error:0.012051	validation_1-error:0.012051	validation_0-f1:0.427425	validation_1-f1:0.427425
# [70]	validation_0-error:0.012024	validation_1-error:0.012024	validation_0-f1:0.429827	validation_1-f1:0.429827
# [71]	validation_0-error:0.012009	validation_1-error:0.012009	validation_0-f1:0.429957	validation_1-f1:0.429957
# [72]	validation_0-error:0.012019	validation_1-error:0.012019	validation_0-f1:0.429614	validation_1-f1:0.429614
# [73]	validation_0-error:0.012002	validation_1-error:0.012002	validation_0-f1:0.431489	validation_1-f1:0.431489
# [74]	validation_0-error:0.011984	validation_1-error:0.011984	validation_0-f1:0.437876	validation_1-f1:0.437876
# [75]	validation_0-error:0.011937	validation_1-error:0.011937	validation_0-f1:0.442795	validation_1-f1:0.442795
# [76]	validation_0-error:0.011941	validation_1-error:0.011941	validation_0-f1:0.443069	validation_1-f1:0.443069
# [77]	validation_0-error:0.011958	validation_1-error:0.011958	validation_0-f1:0.44219	validation_1-f1:0.44219
# [78]	validation_0-error:0.011992	validation_1-error:0.011992	validation_0-f1:0.4396	validation_1-f1:0.4396
# [79]	validation_0-error:0.01195	validation_1-error:0.01195	validation_0-f1:0.443935	validation_1-f1:0.443935
# [80]	validation_0-error:0.011973	validation_1-error:0.011973	validation_0-f1:0.445358	validation_1-f1:0.445358
# [81]	validation_0-error:0.012012	validation_1-error:0.012012	validation_0-f1:0.442118	validation_1-f1:0.442118
# [82]	validation_0-error:0.012003	validation_1-error:0.012003	validation_0-f1:0.442906	validation_1-f1:0.442906
# [83]	validation_0-error:0.011996	validation_1-error:0.011996	validation_0-f1:0.443279	validation_1-f1:0.443279
# [84]	validation_0-error:0.011999	validation_1-error:0.011999	validation_0-f1:0.447504	validation_1-f1:0.447504
# [85]	validation_0-error:0.012004	validation_1-error:0.012004	validation_0-f1:0.447629	validation_1-f1:0.447629
# [86]	validation_0-error:0.011966	validation_1-error:0.011966	validation_0-f1:0.451189	validation_1-f1:0.451189
# [87]	validation_0-error:0.011968	validation_1-error:0.011968	validation_0-f1:0.451432	validation_1-f1:0.451432
# [88]	validation_0-error:0.012021	validation_1-error:0.012021	validation_0-f1:0.447792	validation_1-f1:0.447792
# [89]	validation_0-error:0.012025	validation_1-error:0.012025	validation_0-f1:0.447277	validation_1-f1:0.447277
# [90]	validation_0-error:0.012023	validation_1-error:0.012023	validation_0-f1:0.449247	validation_1-f1:0.449247
# [91]	validation_0-error:0.01203	validation_1-error:0.01203	validation_0-f1:0.448999	validation_1-f1:0.448999
# [92]	validation_0-error:0.011991	validation_1-error:0.011991	validation_0-f1:0.452519	validation_1-f1:0.452519
# [93]	validation_0-error:0.011978	validation_1-error:0.011978	validation_0-f1:0.453728	validation_1-f1:0.453728
# [94]	validation_0-error:0.011989	validation_1-error:0.011989	validation_0-f1:0.453445	validation_1-f1:0.453445
# [95]	validation_0-error:0.012021	validation_1-error:0.012021	validation_0-f1:0.451388	validation_1-f1:0.451388
# [96]	validation_0-error:0.012065	validation_1-error:0.012065	validation_0-f1:0.44782	validation_1-f1:0.44782
# [97]	validation_0-error:0.012028	validation_1-error:0.012028	validation_0-f1:0.452861	validation_1-f1:0.452861
# [98]	validation_0-error:0.012032	validation_1-error:0.012032	validation_0-f1:0.45327	validation_1-f1:0.45327
# [99]	validation_0-error:0.012046	validation_1-error:0.012046	validation_0-f1:0.453312	validation_1-f1:0.453312
# [100]	validation_0-error:0.012069	validation_1-error:0.012069	validation_0-f1:0.4531	validation_1-f1:0.4531
# [101]	validation_0-error:0.012068	validation_1-error:0.012068	validation_0-f1:0.453439	validation_1-f1:0.453439
# Stopping. Best iteration:
# [1]	validation_0-error:0.012532	validation_1-error:0.012532	validation_0-f1:0.370449	validation_1-f1:0.370449
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=0.8, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=10000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=1030,
#               reg_alpha=0, reg_lambda=1e-05, scale_pos_weight=3, seed=None,
#               silent=True, subsample=0.8, verbosity=1)
